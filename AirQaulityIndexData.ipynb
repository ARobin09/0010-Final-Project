# %%
import pandas as pd

# %%
df = pd.read_csv('https://data.wprdc.org/datastore/dump/4ab1e23f-3262-4bd3-adbf-f72f0119108b')

print(df.columns)

ave_aqi = df.groupby('site')['index_value'].mean().reset_index()

ave_aqi.columns = ['site', 'index_value']

ave_aqi = ave_aqi.sort_values(by='index_value', ascending = True)

ave_aqi_filtered = ave_aqi[~ave_aqi['site'].isin(['Liberty 2', 'Lawrenceville 2'])]

print(ave_aqi_filtered)
# Out:
# Index(['_id', 'date', 'site', 'parameter', 'index_value', 'description',
#        'health_advisory', 'health_effects'],
#       dtype='object')
#                      site  index_value
# 14           West Mifflin     6.335548
# 2              Flag Plaza     9.949275
# 3   Glassport High Street    17.385812
# 7                 Liberty    17.963226
# 10         North Braddock    18.790840
# 11           Parkway East    21.642520
# 13          South Fayette    23.843196
# 0                  Avalon    24.242469
# 4       Harrison Township    24.303001
# 12             Pittsburgh    25.075430
# 1                Clairton    27.941498
# 9                 Lincoln    35.108002
# 5           Lawrenceville    37.631623

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.barh(ave_aqi_filtered['site'], ave_aqi_filtered['index_value'], color='seagreen')
plt.xlabel('Location')
plt.ylabel('Average AQI')
plt.title('Average Air Quality Index by Location (Lower is better)')
plt.xticks(rotation=45, ha='right')  
plt.tight_layout()  
plt.show()

# %% [markdown]
# # Analysis
# Based on the above data, we can see that the averages of the above neighborhoods are below 50 in the AQI index, which is the safe zone for air quality. The cleanest neighborhoods in terms of air quality are West Mifflin, FLag Plaza, Glassport High Street, Liberty, and North Braddock. These 5 neighborhoods all have had the lowest average AQI in their data, indicating that they were the cleanest cities compared to the other 13 in the graph above. Note that Lawrenceville 2 and Liberty 2 were dropped from the data set, due to being different measurements of PPI, giving an unfair advantage to both cities.
